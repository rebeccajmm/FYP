# %%
import pandas as pd
import numpy as np
import tkinter as tk
from tkinter import *
import Bio.PDB
import nglview as nv

class Application(Frame):
    def __init__(self, master=None):
        Frame.__init__(self, master)
        self.grid()
        self.master.title("ATPase MitoMap")
        
        #Number of rows and columns in the GUI
        for r in range(8):
            self.master.rowconfigure(r, weight=1)    
        for c in range(12):
            self.master.columnconfigure(c, weight=1)
            
        #Frame 1 sizing
        Frame1 = Frame(master, bg="white", highlightbackground="black", highlightthickness=1)
        Frame1.grid(row = 0, column = 0, rowspan = 8, columnspan = 3, sticky = W+N+E+S)
        
        #Reading csv files of each of the subunits
        alpha = pd.read_csv('alpha.csv')
        alpha = alpha.set_index('Hs prot. no.')
        delta = pd.read_csv('delta.csv')
        delta = delta.set_index('Hs prot. no.')
        epsilon = pd.read_csv('epsilon.csv')
        epsilon = epsilon.set_index('Hs prot. no.')
        a = pd.read_csv('a.csv')
        a = a.set_index('Hs NT no.')
        eight = pd.read_csv('eight.csv')
        eight = eight.set_index('Hs NT no.')
        
        def alpha_disable():
            #Disabling the rest of subunit buttons when alpha is pressed
            button_a.configure(state=DISABLED)
            button_delta.configure(state=DISABLED)
            button_epsilon.configure(state=DISABLED)
            button_eight.configure(state=DISABLED)
            
            #opening variables
            alpha_mut = tk.IntVar()
            alpha_out = StringVar()
            
            def go():
                if alpha_mut.get() in range (1, 555):
                    alpha2 = alpha.loc[[alpha_mut.get()],['Hs NT mut']]
                    
                    #number inputted doesn't have mutation
                    if alpha2.iat[0,0] == 'NO' and alpha2.iat[1,0] == 'NO' and alpha2.iat[2,0] == 'NO':
                        alpha_out.set("No mutation here")
                    
                    #number inputted has a known mutation
                    elif alpha2.iat [0,0] != 'NO' and alpha2.iat[1,0] == 'NO' and alpha2.iat[2,0] == 'NO':   
                        alpha3 = alpha.loc[[alpha_mut.get()],['Hs NT']]
                        letter1 = alpha3.iat[0,0]             
                        alpha4 = alpha.loc[[alpha_mut.get()],['Hs prot.']]
                        letter2 = alpha4.iat[0,0]
                        alpha5 = alpha.loc[[alpha_mut.get()],['Hs prot. mut']]
                        letter3 = alpha5.iat[0,0]
                        alpha6 = alpha.loc[[alpha_mut.get()],['Disease']]
                        disease1 = alpha6.iat[0,0] 
                        
                        alpha16 = alpha.loc[[alpha_mut.get()],['6B8H (chains n/X/W/K/C/B)']]
                        lt1 = alpha16.iat[0,0]
                        alpha17 = alpha.loc[[alpha_mut.get()],['Sc prot.']]
                        lt2 = alpha17.iat[0,0]
                        alpha18 = alpha.loc[[alpha_mut.get()],['5FIK (chains A/B/C)']]
                        lt3 = alpha18.iat[0,0]
                        alpha19 = alpha.loc[[alpha_mut.get()],['Bt prot.']]
                        lt4 = alpha19.iat[0,0]
                        alpha20 = alpha.loc[[alpha_mut.get()],['5FL7 (chains A/B/C)']]
                        lt5 = alpha20.iat[0,0]
                        alpha21 = alpha.loc[[alpha_mut.get()],['Yl prot.']]
                        lt6 = alpha21.iat[0,0]
                        
                        text1 = ('Results:\n\nH.sapiens\n-{}>{}, {}{}{}\n-{}\n\nMapping\nS.cerevisiae (PDB:6B8H)> {}{}\nB.taurus (PDB:5FIK)> {}{}\nY.lipolytica (PDB:5FL7)> {}{}').format(letter1,alpha2.iat[0,0],letter2,alpha_mut.get(),letter3,disease1,lt1,lt2,lt3,lt4,lt5,lt6)
                        alpha_out.set(text1)
                        
                    elif alpha2.iat [0,0] == 'NO' and alpha2.iat[1,0] != 'NO' and alpha2.iat[2,0] == 'NO':
                        alpha7 = alpha.loc[[alpha_mut.get()],['Hs NT']]
                        letter4 = alpha7.iat[1,0] 
                        alpha8 = alpha.loc[[alpha_mut.get()],['Hs prot.']]
                        letter5 = alpha8.iat[1,0]
                        alpha10 = alpha.loc[[alpha_mut.get()],['Hs prot. mut']]
                        letter6 = alpha10.iat[1,0] 
                        alpha11 = alpha.loc[[alpha_mut.get()],['Disease']]
                        disease2 = alpha11.iat[1,0]
                        
                        alpha22 = alpha.loc[[alpha_mut.get()],['6B8H (chains n/X/W/K/C/B)']]
                        lt7 = alpha22.iat[1,0]
                        alpha23 = alpha.loc[[alpha_mut.get()],['Sc prot.']]
                        lt8 = alpha23.iat[1,0]
                        alpha24 = alpha.loc[[alpha_mut.get()],['5FIK (chains A/B/C)']]
                        lt9 = alpha24.iat[1,0]
                        alpha25 = alpha.loc[[alpha_mut.get()],['Bt prot.']]
                        lt10 = alpha25.iat[1,0]
                        alpha26 = alpha.loc[[alpha_mut.get()],['5FL7 (chains A/B/C)']]
                        lt11 = alpha26.iat[1,0]
                        alpha27 = alpha.loc[[alpha_mut.get()],['Yl prot.']]
                        lt12 = alpha27.iat[1,0]
                        
                        text2 = ('Results:\n\nH.sapiens\n-{}>{}, {}{}{}\n-{}\n\nMapping\nS.cerevisiae (PDB:6B8H)> {}{}\nB.taurus (PDB:5FIK)> {}{}\nY.lipolytica (PDB:5FL7)> {}{}').format(letter4,alpha2.iat[1,0],letter5,alpha_mut.get(),letter6,disease2,lt7,lt8,lt9,lt10,lt11,lt12)
                        alpha_out.set(text2)
                        
                    elif alpha2.iat [0,0] == 'NO' and alpha2.iat[1,0] == 'NO' and alpha2.iat[2,0] != 'NO':
                        alpha12 = alpha.loc[[alpha_mut.get()],['Hs NT']]
                        letter7 = alpha12.iat[2,0]  
                        alpha13 = alpha.loc[[alpha_mut.get()],['Hs prot.']]
                        letter8 = alpha13.iat[2,0] 
                        alpha14 = alpha.loc[[alpha_mut.get()],['Hs prot. mut']]
                        letter9 = alpha14.iat[2,0]   
                        alpha15 = alpha.loc[[alpha_mut.get()],['Disease']]
                        disease3 = alpha15.iat[2,0] 
                        
                        alpha28 = alpha.loc[[alpha_mut.get()],['6B8H (chains n/X/W/K/C/B)']]
                        lt13 = delta28.iat[2,0]
                        alpha29 = alpha.loc[[alpha_mut.get()],['Sc prot.']]
                        lt14 = alpha29.iat[2,0]
                        alpha30 = alpha.loc[[alpha_mut.get()],['5FIK (chains A/B/C)']]
                        lt15 = alpha30.iat[2,0]
                        alpha31 = alpha.loc[[alpha_mut.get()],['Bt prot.']]
                        lt16 = alpha31.iat[2,0]
                        alpha32 = alpha.loc[[alpha_mut.get()],['5FL7 (chains A/B/C)']]
                        lt17 = alpha32.iat[2,0]
                        alpha3 = alpha.loc[[alpha_mut.get()],['Yl prot.']]
                        lt18 = alpha33.iat[2,0]
                        
                        text3 = ('Results:\n\nH.sapiens\n-{}>{}, {}{}{}\n-{}\n\nMapping\nS.cerevisiae (PDB:6B8H)> {}{}\nB.taurus (PDB:5FIK)> {}{}\nY.lipolytica (PDB:5FL7)> {}{}').format(letter7,alpha2.iat[2,0],letter8,alpha_mut.get(),letter9,disease3,lt13,lt14,lt15,lt16,lt17,lt18)
                        alpha_out.set(text3)
                        
                #error message in case number inputed is out of range
                else:
                    alpha_out.set("Amino acid number must be between 1 and 554")
            
            #Creating all labels and buttons to input the amino acid number to look at
            label_mutation = Label(Frame1, text="Enter amino acid number: ", bg="white")
            entry_mutation = Entry(Frame1, textvariable=alpha_mut, width=12) 
            button_mutation = Button(Frame1, text="GO!", command=go)
            label_output = Message(Frame1, textvariable=alpha_out, bg="white", width=250)
                    
            label_mutation.grid(row=2, columnspan=3, sticky=W+N)
            entry_mutation.grid(row=3, column=0, sticky=W+N)
            button_mutation.grid(row=3, column=1, sticky=W+N)
            label_output.grid(row=4, columnspan=6, sticky= W+N)
            
        def delta_disable():
            button_a.configure(state=DISABLED)
            button_alpha.configure(state=DISABLED)
            button_epsilon.configure(state=DISABLED)
            button_eight.configure(state=DISABLED)
            
            delta_mut = tk.IntVar()
            delta_out = StringVar()
            
            def go2():  
                if delta_mut.get() in range (1, 169):
                    delta2 = delta.loc[[delta_mut.get()],['Hs NT mut']]  

                    if delta2.iat[0,0] == 'NO' and delta2.iat[1,0] == 'NO' and delta2.iat[2,0] == 'NO':
                        delta_out.set('No mutation here')
                         
                    elif delta2.iat [0,0] != 'NO' and delta2.iat[1,0] == 'NO' and delta2.iat[2,0] == 'NO':   
                        delta3 = delta.loc[[delta_mut.get()],['Hs NT']]
                        letter1 = delta3.iat[0,0]   
                        delta4 = delta.loc[[delta_mut.get()],['Hs prot.']]
                        letter2 = delta4.iat[0,0]
                        delta5 = delta.loc[[delta_mut.get()],['Hs prot. mut']]
                        letter3 = delta5.iat[0,0]
                        delta6 = delta.loc[[delta_mut.get()],['Disease']]
                        disease1 = delta6.iat[0,0] 
                        
                        delta16 = delta.loc[[delta_mut.get()],['6B8H (chains H/l)']]
                        lt1 = delta16.iat[0,0]
                        delta17 = delta.loc[[delta_mut.get()],['Sc prot.']]
                        lt2 = delta17.iat[0,0]
                        delta18 = delta.loc[[delta_mut.get()],['5FIK (chain H)']]
                        lt3 = delta18.iat[0,0]
                        delta19 = delta.loc[[delta_mut.get()],['Bt prot.']]
                        lt4 = delta19.iat[0,0]
                        delta20 = delta.loc[[delta_mut.get()],['5FL7 (chain H)']]
                        lt5 = delta20.iat[0,0]
                        delta21 = delta.loc[[delta_mut.get()],['Yl prot.']]
                        lt6 = delta21.iat[0,0]
                        
                        text1 = ('Results:\n\nH.sapiens\n-{}>{}, {}{}{}\n-{}\n\nMapping\nS.cerevisiae (PDB:6B8H)> {}{}\nB.taurus (PDB:5FIK)> {}{}\nY.lipolytica (PDB:5FL7)> {}{}').format(letter1,delta2.iat[0,0],letter2,delta_mut.get(),letter3,disease1,lt1,lt2,lt3,lt4,lt5,lt6)
                        delta_out.set(text1)
                        
                    elif delta2.iat [0,0] == 'NO' and delta2.iat[1,0] != 'NO' and delta2.iat[2,0] == 'NO':
                        delta7 = delta.loc[[delta_mut.get()],['Hs NT']]
                        letter4 = delta7.iat[1,0]   
                        delta8 = delta.loc[[delta_mut.get()],['Hs prot.']]
                        letter5 = delta8.iat[1,0]  
                        delta10 = delta.loc[[delta_mut.get()],['Hs prot. mut']]
                        letter6 = delta10.iat[1,0]   
                        delta11 = delta.loc[[delta_mut.get()],['Disease']]
                        disease2 = delta11.iat[1,0] 
                        
                        delta22 = delta.loc[[delta_mut.get()],['6B8H (chains H/l)']]
                        lt7 = delta22.iat[1,0]
                        delta23 = delta.loc[[delta_mut.get()],['Sc prot.']]
                        lt8 = delta23.iat[1,0]
                        delta24 = delta.loc[[delta_mut.get()],['5FIK (chain H)']]
                        lt9 = delta24.iat[1,0]
                        delta25 = delta.loc[[delta_mut.get()],['Bt prot.']]
                        lt10 = delta25.iat[1,0]
                        delta26 = delta.loc[[delta_mut.get()],['5FL7 (chain H)']]
                        lt11 = delta26.iat[1,0]
                        delta27 = delta.loc[[delta_mut.get()],['Yl prot.']]
                        lt12 = delta27.iat[1,0]
                        
                        text2 = ('Results:\n\nH.sapiens\n-{}>{}, {}{}{}\n-{}\n\nMapping\nS.cerevisiae (PDB:6B8H)> {}{}\nB.taurus (PDB:5FIK)> {}{}\nY.lipolytica (PDB:5FL7)> {}{}').format(letter4,delta2.iat[1,0],letter5,delta_mut.get(),letter6,disease2,lt7,lt8,lt9,lt10,lt11,lt12)
                        delta_out.set(text2)
                        
                    elif delta2.iat [0,0] == 'NO' and delta2.iat[1,0] == 'NO' and delta2.iat[2,0] != 'NO':
                        delta12 = delta.loc[[delta_mut.get()],['Hs NT']]
                        letter7 = delta12.iat[2,0]
                        delta13 = delta.loc[[delta_mut.get()],['Hs prot.']]
                        letter8 = delta13.iat[2,0]
                        delta14 = delta.loc[[delta_mut.get()],['Hs prot. mut']]
                        letter9 = delta14.iat[2,0] 
                        delta15 = delta.loc[[delta_mut.get()],['Disease']]
                        disease3 = delta15.iat[2,0] 
                        
                        delta28 = delta.loc[[delta_mut.get()],['6B8H (chains H/l)']]
                        lt13 = delta28.iat[2,0]
                        delta29 = delta.loc[[delta_mut.get()],['Sc prot.']]
                        lt14 = delta29.iat[2,0]
                        delta30 = delta.loc[[delta_mut.get()],['5FIK (chain H)']]
                        lt15 = delta30.iat[2,0]
                        delta31 = delta.loc[[delta_mut.get()],['Bt prot.']]
                        lt16 = delta31.iat[2,0]
                        delta32 = delta.loc[[delta_mut.get()],['5FL7 (chain H)']]
                        lt17 = delta32.iat[2,0]
                        delta3 = delta.loc[[delta_mut.get()],['Yl prot.']]
                        lt18 = delta33.iat[2,0]
                        
                        text3 = ('Results:\n\nH.sapiens\n-{}>{}, {}{}{}\n-{}\n\nMapping\nS.cerevisiae (PDB:6B8H)> {}{}\nB.taurus (PDB:5FIK)> {}{}\nY.lipolytica (PDB:5FL7)> {}{}').format(letter7,delta2.iat[2,0],letter8,delta_mut.get(),letter9,disease3,lt13,lt14,lt15,lt16,lt17,lt18)
                        delta_out.set(text3)
                else:
                    delta_out.set('Amino acid number must be between 1 and 168')
            
            label_mutation = Label(Frame1, text="Enter amino acid number: ", bg="white")
            entry_mutation = Entry(Frame1, textvariable=delta_mut, width=12) 
            button_mutation = Button(Frame1, text="GO!", command=go2)
            label_output = Message(Frame1, textvariable=delta_out, bg="white", width=250)
                    
            label_mutation.grid(row=2, columnspan=3, sticky=W+N)
            entry_mutation.grid(row=3, column=0, sticky=W+N)
            button_mutation.grid(row=3, column=1, sticky=W+N)
            label_output.grid(row=4, columnspan=6, sticky= W+N)
            
        def epsilon_disable():
            button_a.configure(state=DISABLED)
            button_delta.configure(state=DISABLED)
            button_alpha.configure(state=DISABLED)
            button_eight.configure(state=DISABLED)
            
            epsilon_mut = tk.IntVar()
            epsilon_out = StringVar()
            
            def go3():   
                if epsilon_mut.get() in range (1, 52):
                    epsilon2 = epsilon.loc[[epsilon_mut.get()],['Hs NT mut']]  

                    if epsilon2.iat[0,0] == 'NO' and epsilon2.iat[1,0] == 'NO' and epsilon2.iat[2,0] == 'NO':
                        epsilon_out.set('No mutation here')
                        
                    elif epsilon2.iat [0,0] != 'NO' and epsilon2.iat[1,0] == 'NO' and epsilon2.iat[2,0] == 'NO':   
                        epsilon3 = epsilon.loc[[epsilon_mut.get()],['Hs NT']]
                        letter1 = epsilon3.iat[0,0] 
                        epsilon4 = epsilon.loc[[epsilon_mut.get()],['Hs prot.']]
                        letter2 = delta4.iat[0,0]
                        epsilon5 = epsilon.loc[[epsilon_mut.get()],['Hs prot. mut']]
                        letter3 = epsilon5.iat[0,0]
                        epsilon6 = epsilon.loc[[epsilon_mut.get()],['Disease']]
                        disease1 = epsilon6.iat[0,0] 
                        
                        epsilon16 = epsilon.loc[[epsilon_mut.get()],['6B8H (chains l/m)']]
                        lt1 = epsilon16.iat[0,0]
                        epsilon17 = epsilon.loc[[epsilon_mut.get()],['Sc prot.']]
                        lt2 = epsilon17.iat[0,0]
                        epsilon18 = epsilon.loc[[epsilon_mut.get()],['5FIK (chain I)']]
                        lt3 = epsilon18.iat[0,0]
                        epsilon19 = epsilon.loc[[epsilon_mut.get()],['Bt prot.']]
                        lt4 = epsilon19.iat[0,0]
                        epsilon20 = epsilon.loc[[epsilon_mut.get()],['5FL7 (chain I)']]
                        lt5 = epsilon20.iat[0,0]
                        epsilon21 = epsilon.loc[[epsilon_mut.get()],['Yl prot.']]
                        lt6 = epsilon21.iat[0,0]
                        
                        text1 = ('Results:\n\nH.sapiens\n-{}>{}, {}{}{}\n-{}\n\nMapping\nS.cerevisiae (PDB:6B8H)> {}{}\nB.taurus (PDB:5FIK)> {}{}\nY.lipolytica (PDB:5FL7)> {}{}').format(letter1,epsilon2.iat[0,0],letter2,epsilon_mut.get(),letter3,disease1,lt1,lt2,lt3,lt4,lt5)
                        epsilon_out.set(text1)
                        
                    elif epsilon2.iat [0,0] == 'NO' and epsilon2.iat[1,0] != 'NO' and epsilon2.iat[2,0] == 'NO':
                        epsilon7 = epsilon.loc[[epsilon_mut.get()],['Hs NT']]
                        letter4 = epsilon7.iat[1,0]
                        epsilon8 = epsilon.loc[[epsilon_mut.get()],['Hs prot.']]
                        letter5 = epsilon8.iat[1,0]
                        epsilon10 = epsilon.loc[[epsilon_mut.get()],['Hs prot. mut']]
                        letter6 = epsilon10.iat[1,0]    
                        epsilon11 = epsilon.loc[[epsilon_mut.get()],['Disease']]
                        disease2 = epsilon11.iat[1,0] 
                        
                        epsilon22 = epsilon.loc[[epsilon_mut.get()],['6B8H (chains l/m)']]
                        lt7 = epsilon22.iat[1,0]
                        epsilon23 = epsilon.loc[[epsilon_mut.get()],['Sc prot.']]
                        lt8 = epsilon23.iat[1,0]
                        epsilon24 = epsilon.loc[[epsilon_mut.get()],['5FIK (chain I)']]
                        lt9 = epsilon24.iat[1,0]
                        epsilon25 = epsilon.loc[[epsilon_mut.get()],['Bt prot.']]
                        lt10 = epsilon25.iat[1,0]
                        epsilon26 = epsilon.loc[[epsilon_mut.get()],['5FL7 (chain I)']]
                        lt11 = epsilon26.iat[1,0]
                        epsilon27 = epsilon.loc[[epsilon_mut.get()],['Yl prot.']]
                        lt12 = epsilon27.iat[1,0]
                        
                        text2 = ('Results:\n\nH.sapiens\n-{}>{}, {}{}{}\n-{}\n\nMapping\nS.cerevisiae (PDB:6B8H)> {}{}\nB.taurus (PDB:5FIK)> {}{}\nY.lipolytica (PDB:5FL7)> {}{}').format(letter4,epsilon2.iat[1,0],letter5,epsilon_mut.get(),letter6,disease2,lt7,lt8,lt9,lt10,lt11,lt12)
                        epsilon_out.set(text2)
                        
                    elif epsilon2.iat [0,0] == 'NO' and epsilon2.iat[1,0] == 'NO' and epsilon2.iat[2,0] != 'NO':
                        epsilon12 = epsilon.loc[[epsilon_mut.get()],['Hs NT']]
                        letter7 = epsilon12.iat[2,0]
                        epsilon13 = epsilon.loc[[epsilon_mut.get()],['Hs prot.']]
                        letter8 = epsilon13.iat[2,0]
                        epsilon14 = epsilon.loc[[epsilon_mut.get()],['Hs prot. mut']]
                        letter9 = epsilon14.iat[2,0] 
                        epsilon15 = epsilon.loc[[epsilon_mut.get()],['Disease']]
                        disease3 = epsilon15.iat[2,0] 
                        
                        epsilon28 = epsilon.loc[[epsilon_mut.get()],['6B8H (chains l/m)']]
                        lt13 = epsilon28.iat[2,0]
                        epsilon29 = epsilon.loc[[epsilon_mut.get()],['Sc prot.']]
                        lt14 = epsilon29.iat[2,0]
                        epsilon30 = epsilon.loc[[epsilon_mut.get()],['5FIK (chain I)']]
                        lt15 = epsilon30.iat[2,0]
                        epsilon31 = epsilon.loc[[epsilon_mut.get()],['Bt prot.']]
                        lt16 = epsilon31.iat[2,0]
                        epsilon32 = epsilon.loc[[epsilon_mut.get()],['5FL7 (chain I)']]
                        lt17 = epsilon32.iat[2,0]
                        epsilon33 = epsilon.loc[[epsilon_mut.get()],['Yl prot.']]
                        lt18 = epsilon33.iat[2,0]
                        
                        text3 = ('Results:\n\nH.sapiens\n-{}>{}, {}{}{}\n-{}\n\nMapping\nS.cerevisiae (PDB:6B8H)> {}{}\nB.taurus (PDB:5FIK)> {}{}\nY.lipolytica (PDB:5FL7)> {}{}').format(letter7,epsilon2.iat[2,0],letter8,epsilon_mut.get(),letter9,disease3,lt13,lt14,lt15,lt16,lt17,lt18)
                        epsilon_out.set(text3)
                else:
                    epsilon_out.set('Amino acid number must be between 1 and 51')
            
            label_mutation = Label(Frame1, text="Enter amino acid number: ", bg="white")
            entry_mutation = Entry(Frame1, textvariable=epsilon_mut, width=12) 
            button_mutation = Button(Frame1, text="GO!", command=go3)
            label_output = Message(Frame1, textvariable=epsilon_out, bg="white", width=250)
                    
            label_mutation.grid(row=2, columnspan=3, sticky=W+N)
            entry_mutation.grid(row=3, column=0, sticky=W+N)
            button_mutation.grid(row=3, column=1, sticky=W+N)
            label_output.grid(row=4, columnspan=6, sticky= W+N)
            
        def a_disable():
            button_alpha.configure(state=DISABLED)
            button_delta.configure(state=DISABLED)
            button_epsilon.configure(state=DISABLED)
            button_eight.configure(state=DISABLED)
            
            a_mut = tk.IntVar()
            a_out = StringVar()
            
            def go4():      
                if a_mut.get() in range (8527, 9208):
                    a2 = a.loc[[a_mut.get()],['Hs NT mut']]
    
                    if a2.iat[0,0] == 'NO':
                        a_out.set('No mutation here')
                
                    else:    
                        letter1 = a.loc[a_mut.get(), 'Hs NT']
                        letter2 = a.loc[a_mut.get(), 'Hs NT mut']
                        letter3 = a.loc[a_mut.get(), 'Hs prot.']
                        number1 = a.loc[a_mut.get(), 'Hs prot. no.']
                        letter4 = a.loc[a_mut.get(), 'Hs prot. mut']
                        disease = a.loc[a_mut.get(), 'Disease']
                        number2 = a.loc[a_mut.get(), '6B8H (chains a/p)']
                        letter5 = a.loc[a_mut.get(), 'Sc prot.']
                        number3 = a.loc[a_mut.get(), '5FIK (chain W)']
                        letter6 = a.loc[a_mut.get(), 'Bt prot.']
              
                        text = ('Results:\n\nH.sapiens\n-{}>{}, {}{}{}\n-{}\n\nMapping\nS.cerevisiae (PDB:6B8H)> {}{}\nB.taurus (PDB:5FIK)> {}{}').format(letter1,letter2,letter3,number1,letter4,disease,number2,letter5,number3,letter6)
                        a_out.set(text)

                else:
                    a_out.set('Nucleotide number must be between 8527 and 9208')
            
            label_mutation = Label(Frame1, text="Enter nucleotide number: ", bg="white")
            entry_mutation = Entry(Frame1, textvariable=a_mut, width=12) 
            button_mutation = Button(Frame1, text="GO!", command=go4)
            label_output = Message(Frame1, textvariable=a_out, bg="white", width=250)
                    
            label_mutation.grid(row=2, columnspan=3, sticky=W+N)
            entry_mutation.grid(row=3, column=0, sticky=W+N)
            button_mutation.grid(row=3, column=1, sticky=W+N)
            label_output.grid(row=4, columnspan=6, sticky= W+N)
            
        def eight_disable():
            button_a.configure(state=DISABLED)
            button_delta.configure(state=DISABLED)
            button_epsilon.configure(state=DISABLED)
            button_alpha.configure(state=DISABLED)
            
            eight_mut = tk.IntVar()
            eight_out = StringVar()
            
            def go5():       
                if eight_mut.get() in range (8366, 8573):
                    eight2 = eight.loc[[eight_mut.get()],['Hs NT mut']]
    
                    if eight2.iat[0,0] == 'NO':
                        eight_out.set('No mutation here')
                    else:
                        letter1 = eight.loc[eight_mut.get(), 'Hs NT']
                        letter2 = eight.loc[eight_mut.get(), 'Hs NT mut']
                        letter3 = eight.loc[eight_mut.get(), 'Hs prot.']
                        number1 = eight.loc[eight_mut.get(), 'Hs prot. no.']
                        letter4 = eight.loc[eight_mut.get(), 'Hs prot. mut']
                        disease = eight.loc[eight_mut.get(), 'Disease']
                        number2 = eight.loc[eight_mut.get(), '6B8H (chains A/V)']
                        letter5 = eight.loc[eight_mut.get(), 'Sc prot.']
                        
                        text = ('Results:\n\nH.sapiens\n-{}>{}, {}{}{}\n-{}\n\nMapping\nS.cerevisiae (PDB:6B8H)> {}{}').format(letter1,letter2,letter3,number1,letter4,disease,number2,letter5)
                        eight_out.set(text)
                else:
                    eight_out.set('Nucleotide number must be between 8366 and 8572')
            
            label_mutation = Label(Frame1, text="Enter nucleotide number: ", bg="white")
            entry_mutation = Entry(Frame1, textvariable=eight_mut, width=12) 
            button_mutation = Button(Frame1, text="GO!", command=go5)
            label_output = Message(Frame1, textvariable=eight_out, bg="white", width=250)
                    
            label_mutation.grid(row=2, columnspan=3, sticky=W+N)
            entry_mutation.grid(row=3, column=0, sticky=W+N)
            button_mutation.grid(row=3, column=1, sticky=W+N)
            label_output.grid(row=4, columnspan=6, sticky= W+N)
        
        #resetting all button functionalities in case another subunit wants to be searched
        def reset_normal():
            button_alpha.configure(state=NORMAL)
            button_a.configure(state=NORMAL)
            button_delta.configure(state=NORMAL)
            button_epsilon.configure(state=NORMAL)
            button_eight.configure(state=NORMAL)
            
            label_clean = Listbox(Frame1, bg="white", relief='flat', highlightbackground="white")
            label_clean.grid(row=4, columnspan=6, sticky= W+N+E+S)
    
        #labels and buttons that appear when initializing GUI
        label_subunit = Label(Frame1, bg="white", text="Choose subunit:")
        button_alpha = Button(Frame1, text="Alpha", command=alpha_disable)
        button_delta = Button(Frame1, text="Delta", command=delta_disable)
        button_epsilon = Button(Frame1, text="Epsilon", command=epsilon_disable)
        button_a = Button(Frame1, text="A", command=a_disable)
        button_eight = Button(Frame1, text="Eight", command=eight_disable)
        button_reset = Button(Frame1, text="Reset", command=reset_normal, bg='#c8fef2')
        
        label_subunit.grid(row=0,column=0, sticky= W+N)
        button_alpha.grid(row=1, column=1)
        button_a.grid(row=1, column=4)
        button_eight.grid(row=1, column=5)
        button_delta.grid(row=1, column=2)
        button_epsilon.grid(row=1, column=3)
        button_reset.grid(row=1, column=0, sticky = W+N)
     
        #potential second frame for interactive molecular viewer
        Frame2 = Frame(master, bg="blue", highlightbackground="black", highlightthickness=1)
        Frame2.grid(row = 0, column = 2, rowspan = 8, columnspan = 10, sticky = W+E+N+S)
        
        def structure():
            pdb_code1 = '6b8h'
            pdb_filename1 = '6b8h.pdb'
            structure1 = Bio.PDB.PDBParser().get_structure(pdb_code1,pdb_filename1)
            view1 = nv.show_biopython(structure1)

        button_click = Button(Frame2, text="Click", command=structure)
        button_click.grid(row=0, column=0)
   
root = Tk()
root.geometry("1000x500")
root.iconbitmap("atpase.ico")
app = Application(master=root)
app.mainloop()
